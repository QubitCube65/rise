# %% [markdown]
# ## Turn your notebooks into slideshows

# %% [markdown]
# Press `Space` to proceed.

# %% [markdown]
# You can write a regular Jupyter notebook, with the usual mix of markdown and code cells (keep on pressing `Space`).

# %% [markdown]
# In code cells you press `Shift-Enter` as usual to evaluate your code (but for now press `Space` again).

# %% [markdown]
# Disclaimer:
# The following animation requires the installation of 'matplotlib', 'ipywidgets', and 'numpy'.
# Please consider installing these packages (e.g., via 'pip install') to run the cells below.
# These are powerful, heavy-weight libraries used here to provide an interactive visualization of the translation by variable change.

# %% [markdown]
# # This is where you press Shift-Enter
# import numpy as np
# import matplotlib.pyplot as plt
# plt.ion()
#
# "Hello world"

# %% [markdown]
# But apart from that, `Space` is your friend!

# %% [markdown]
# You're in a browser, so remember that you can always use smaller / larger fonts with keyboard shortcuts like `Alt +` and `Alt -` or similar (it could be `Ctrl` instead of `Alt` depending on the platform you are on).
#
# <div style="font-size: 50%"> ideally, the following 2 cells are shown side-by-side, at least that was the case with the old-school classic notebook</div>

# %%
# of course you can show figures
# %pip install numpy matplotlib
import numpy as np
import matplotlib.pyplot as plt

def polynom(x):
    return 2 * x**2 - 20 * x + 2

X = np.linspace(-10, 10)
Y = polynom(X)
plt.plot(X, Y);
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# and everything works as usual

# an animation to illustrate 
# translation by variable change
import ipywidgets as widgets
from ipywidgets import interact, FloatSlider
import matplotlib.pyplot as plt



def parabolic(offset):
    X = np.linspace(-10, 10)
    Y = polynom(X-offset)
    # use same y scale for all offsets
    
    plt.gca().set_ylim([-100, 500])
    plt.plot(X, Y);
    
interact(parabolic, 
         offset=FloatSlider(min=-10., max=10.,
                           step=0.25));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='offset', max=10.0, min=-10.0, step=0.25), Output()),…

# %% [markdown]
# # The RISE notebook extension

# %% [markdown]
# All this is achieved through the RISE notebook extension.
#
# See full documentation at http://rise.readthedocs.io/.

# %% [markdown]
# # Thanks to reveal.js

# %% [markdown]
# The underlying tool is [reveal.js](https://revealjs.com/), and it supports a lot of cool features.

# %% [markdown]
# For example you can organize your show into:
#
# * slides (left to right)
# * subslides (top to bottom)
# * fragments (stops inside a slide)

# %% [markdown]
# You do not need to worry, just press `Space` to proceed along the main line.

# %% [markdown]
# For example this is a subslide; observe the cursor in the bottom right corner.

# %% [markdown]
# If you press `Shift-Space` - here or anywhere else - you will go backwards, so here it would be up.

# %% [markdown]
# # Speaker notes

# %% [markdown]
# If you now press `t` you should see a second window open, with a presenter view, that shows *Notes* cells - that won't show up in the main slides.

# %% [markdown]
# This is an example of a *Notes* cell.

# %% [markdown]
# Next, we'll cover how to tag cells as *Slide*, *SubSlide*, *Fragment* or *Notes*.

# %% [markdown]
# # How to create slideshows

# %% [markdown]
# ### Step 1: Enable slideshow via the Property inspector

# %% [markdown]
# ![](slideshow_toolbar.png)

# %% [markdown]
# ### Step 2:  Assign appropriate slide tags to each cell

# %% [markdown]
# From the standard toolbar...
#
# ![](cell_toolbar.png)

# %% [markdown]
# or, in command mode, use keyboard shortcuts
#
# * `shift-i` : toggle slide
# * `shift-b` : toggle subslide
# * `shift-g` : toggle fragment

# %% [markdown]
# # CSS

# %% [markdown]
# The following files load without additional configuration:
#
# * `rise.css` in the current directory
# * `README.css` for this notebook because it is called `README.ipynb`
#
# If successful, the cell below will show a thick border and a large south-east border-radius.

# %% [markdown]
# ## How to load CSS files:

# %% [markdown]
# ### Option 1: Embed the CSS file in the first Markdown cell
#
#
# ```javascript
#
# <style>
# @import url("README.css");
# </style>
#
#   ```

# %% [markdown]
# ### Option 2: Using Notebook Metadata via Advanced Tools
#
# ```javascript
#     ...
#
#     "rise": {
#         "css": [
#             "overlay.css"
#         ]
#          ...
#     }
#   ```

# %% [markdown]
# # Sample code cell
# message = "My look is changed by both rise.css and README.css"
# <div class="rise cell code_cell rendered"> My look is changed by both rise.css and README.css</div>

# %% [markdown]
# # Publishing on binder

# %% [markdown]
# In order for a binder-hosted notebook to start in slideshow mode, you need to have the following tag set in the notebook metadata:
#
# ```javascript
#     ...
#     "rise": {
#         "autolaunch": true
#     }
#     ...
# ```

# %% [markdown]
# You can edit the notebook metadata in the the `Proberty Inspector` menu,  under Advance Tools  submenu `Notebook metadata`.
#
# Note finally that the `rise` key in this JSON file used to be named `livereveal`. The latter is still honored, but the former takes precedence, and it is recommended to use only `rise` from now on.

# %% [markdown]
# ![](notebook_metadata.png)

# %% [markdown]
# # Chalkboard

# %% [markdown]
# As an option, you can turn on the *chalkboard* reveal plugin, that manifests itself with two extra buttons in the lower left area, that let you add free drawings on your slides.

# %% [markdown]
# This option is turned on, in the notebook metadata again, with:
#
# ```javascript
#     ...
#     "rise": {
#       "enable_chalkboard": true
#     }
#     ...
# ```

# %% [markdown]
# # Tables

# %% [markdown]
# Mostly for checking the rendering of tables, here's a few samples

# %%
# first using pandas

import seaborn as sns
titanic = sns.load_dataset('titanic')
columns = "survived	pclass	sex	age	embarked	class	who	adult_male".split()
titanic[columns].head(8)

# %% [markdown]
# and the same but inlined as markdown
#
# |    |   survived |   pclass | sex    |   age | embarked   | class   | who   | adult_male   |
# |---:|-----------:|---------:|:-------|------:|:-----------|:--------|:------|:-------------|
# |  0 |          0 |        3 | male   |    22 | S          | Third   | man   | True         |
# |  1 |          1 |        1 | female |    38 | C          | First   | woman | False        |
# |  2 |          1 |        3 | female |    26 | S          | Third   | woman | False        |
# |  3 |          1 |        1 | female |    35 | S          | First   | woman | False        |
# |  4 |          0 |        3 | male   |    35 | S          | Third   | man   | True         |
# |  5 |          0 |        3 | male   |   nan | Q          | Third   | man   | True         |
# |  6 |          0 |        1 | male   |    54 | S          | First   | man   | True         |
# |  7 |          0 |        3 | male   |     2 | S          | Third   | child | False        |

# %% [markdown]
# # Decorating all slides
# RISE offers two ways to insert a static background. You can either define an overlay, which gives you full control, or you can define the header, footer, and background image individually.
#
# Note: If you define an overlay, the header, footer, and background image options will be ignored.

# %% [markdown]
# ## Overlay
# It is possible to add the config option overlay to build a constant background.
# It is wrapped in a ```<div> ```, so it can be text or html.
# In this case, the user is entirely responsible for styling.
#
# For example:
#
# ```
# {
#  ...
#  "rise": {
#      "overlay": "<div class='myheader'><h2>my company</h2></div><div class='myfooter'><h2>the date</h2></div>"
#  }
# }
# ```

# %% [markdown]
# ## Header, footer and backimage
# As a more limited, but often more convenient alternative, you can define any of the following 3 settings.
#
# In this case, minimal styling is applied (floor and ceiling), but user is still responsible for cosmetic styling:
# ```
#  ...
# "rise": {
#         "backimage": "examples/mybackimage.png",
#         "header": "<div style='position: fixed; top: 10px; left: 20px; font-size: 18px; color: #333; z-index: 1000;'>📊 My Presentation</div>",
#         "footer": "<div style='position: fixed; bottom: 10px; left: 20px; font-size: 14px; color: #666; z-index: 1000;'>&copy; Moderator</div><div style='position: fixed; bottom: 10px; right: 20px; font-size: 14px; color: #666; z-index: 1000;'>Page <span class='slide-number'></span></div>"
#     }
#
# ```

# %% [markdown]
# ## There are two ways to configure the header and footer:

# %% [markdown]
# ### Option 1: Via notebook metadata:
#
#  ![](header_footer_metadata.png)

# %% [markdown]
# ### Option 2: Via the rise settings:
#
# ![](header_footer_rise_setting.png)

# %% [markdown]
# ## Background image:

# %% [markdown]
# ### Global background image (via CSS):
# To apply a background image to all slides in your RISE presentation, add the following rule to your CSS file:
# ```
# {
# body.rise-enabled .reveal .slides section {
#   background-image: url("mybackimage.png");
#   background-size: cover;
#   background-position: center;
#   background-repeat: no-repeat;
# }
#
# ```
# Import the CSS file in a Markdown cell at the top of your notebook:
#
# ```
# <style>
# @import url("example.css");
# </style>
#
# ```
# Once loaded, the background image will be applied automatically when entering RISE presentation mode.

# %% [markdown]
# ### Slide-specific background image:
# To apply a background image to a single slide only, use a slide-specific CSS class.
#
# 1. Define the Background in CSS:
# Refer to README.css for additional customization options.
#
#  2. Apply to the Markdown Cell:
# Use the following syntax within your Markdown cell to target the slide:
#
# ```
# <div class="backimage"></div>
#
# ```
# <div class="backimage"></div>

# %% [markdown]
# ## Applying a theme to your notebook:
#
# Set your desired reveal.js theme in the notebook metadata:
# ```
# ...
#     "rise": {
#         "theme": "beige"
#     }
# ```
#
# ![](theme_metadata.png)
#
#
# ```

# %% [markdown]
# Alternatively, you can select and adjust the theme using the RISE settings panel:
#
# ![](theme_setting.png)
#
# To ensure the theme background is fully visible, include the Theme.css file in your notebook by adding the following snippet to the first Markdown cell:
# ```
# <style>
# @import url("Theme.css");
# </style>
